# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
    
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0    # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words    # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5236, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window    # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('        batch:', [reverse_dictionary[bi] for bi in batch])
    print('        labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#         batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#         labels: ['as', 'anarchism', 'a', 'originated', 'as', 'term', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#         batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#         labels: ['a', 'term', 'anarchism', 'originated', 'term', 'as', 'originated', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                                                 stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                                                             labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.158379
# Nearest to more: appliances, sprache, reductive, hedgehog, farley, micha, doubt, pharaoh,
# Nearest to known: ordinary, red, gouvernement, polymer, commutation, intra, doubt, flavouring,
# Nearest to there: cyrene, nautilus, gbase, codify, schenectady, mottled, unmatched, inconvenient,
# Nearest to d: tipped, bypassed, castel, varuna, miscellany, araki, brains, auburn,
# Nearest to states: chester, univ, praetor, sveriges, manufacture, threatened, oppose, downstream,
# Nearest to b: axons, elevations, aims, imprecise, romanov, directv, aladdin, competitors,
# Nearest to two: escapes, epr, hasmonaean, attentive, oubangui, intervocalic, lomond, circuses,
# Nearest to many: stratofortress, rudi, beale, therapy, practitioners, ludo, waco, geelong,
# Nearest to first: constructors, projectile, webern, cliffs, galvanized, structurally, recorded, blinding,
# Nearest to that: vj, tim, dumb, hybrids, bester, marriageable, tongue, neighbourhoods,
# Nearest to for: rembrandt, ellington, renders, soo, mind, overwhelmed, inaugurated, contain,
# Nearest to is: disappeared, darmstadt, galtieri, shanghainese, noonan, actually, resolver, lock,
# Nearest to these: albornoz, resilient, baer, bridged, filioque, clintons, zapotec, avatar,
# Nearest to time: meyers, whitey, cafes, swell, memorials, rigidly, stimulate, hypothetically,
# Nearest to over: kv, borrows, cadiz, uranhay, doyle, ypres, vis, outings,
# Nearest to not: verifiable, filioque, jaber, cordwainer, repudiating, aborted, engineering, serve,
# Average loss at step 2000: 4.367570
# Average loss at step 4000: 3.864035
# Average loss at step 6000: 3.786985
# Average loss at step 8000: 3.689335
# Average loss at step 10000: 3.619500
# Nearest to more: appliances, less, nast, whist, liege, pharaoh, breaker, farley,
# Nearest to known: well, regarded, pollinators, logudorese, avicenna, bonzos, codes, schism,
# Nearest to there: it, they, he, domitius, cyrene, not, unmatched, codify,
# Nearest to d: b, varuna, and, araki, derry, tipped, dulcimer, mcgovern,
# Nearest to states: carrot, univ, charismatic, nations, kriegsmarine, chester, chrono, downstream,
# Nearest to b: d, axons, brainstem, rightmost, elevations, yassin, imprecise, human,
# Nearest to two: five, four, six, three, eight, nine, one, seven,
# Nearest to many: some, several, ludo, kitab, rudi, fads, practitioners, competence,
# Nearest to first: constructors, webern, projectile, blinding, puddle, patti, jacquard, oc,
# Nearest to that: which, sole, ciphertext, vj, it, dumb, shin, what,
# Nearest to for: after, tien, at, atheroma, of, harpist, briand, christiaan,
# Nearest to is: was, are, has, questioned, honorary, be, lille, toot,
# Nearest to these: all, filioque, trouv, many, masking, weather, sufficed, dial,
# Nearest to time: buds, cafes, swell, meyers, whitey, soddy, climate, hypothetically,
# Nearest to over: fpga, discourage, vis, borrows, maud, gren, kv, moroni,
# Nearest to not: they, to, also, serve, it, there, hung, illiterate,
# Average loss at step 12000: 3.600185
# Average loss at step 14000: 3.573205
# Average loss at step 16000: 3.409528
# Average loss at step 18000: 3.458649
# Average loss at step 20000: 3.541623
# Nearest to more: less, very, most, nast, appliances, anglicised, pharaoh, ethnographic,
# Nearest to known: regarded, well, served, used, pollinators, bonzos, such, avicenna,
# Nearest to there: it, they, he, which, who, also, not, but,
# Nearest to d: b, varuna, ochre, fortified, derry, darkness, araki, prevented,
# Nearest to states: nations, univ, charismatic, kneel, carrot, kingdom, downstream, stabilization,
# Nearest to b: d, brainstem, elevations, rightmost, frisbee, lookup, happiest, fock,
# Nearest to two: five, four, six, three, eight, seven, zero, one,
# Nearest to many: some, several, other, these, all, kitab, cities, comoros,
# Nearest to first: webern, jacquard, financial, constructors, next, second, projectile, nsc,
# Nearest to that: which, but, turret, this, sole, what, however, daikaiju,
# Nearest to for: by, of, after, and, through, from, with, creates,
# Nearest to is: was, has, are, were, be, honorary, georgy, but,
# Nearest to these: many, all, some, masking, which, filioque, other, trouv,
# Nearest to time: buds, deceive, cafes, floss, mediaeval, professionally, swell, change,
# Nearest to over: fpga, discourage, gren, vis, sasquatch, moroni, outings, deluge,
# Nearest to not: also, to, liu, they, foresaw, now, you, hung,
# Average loss at step 22000: 3.498193
# Average loss at step 24000: 3.493154
# Average loss at step 26000: 3.482232
# Average loss at step 28000: 3.479852
# Average loss at step 30000: 3.501539
# Nearest to more: less, very, most, pharaoh, fairly, ethnographic, appliances, too,
# Nearest to known: regarded, used, well, served, such, pollinators, defined, referred,
# Nearest to there: they, it, he, still, often, who, we, not,
# Nearest to d: b, ochre, rightmost, bavaria, widower, varuna, derry, fellowships,
# Nearest to states: nations, kingdom, univ, state, kneel, kriegsmarine, crystallography, downstream,
# Nearest to b: d, brainstem, fortified, frisbee, rightmost, refreshed, lookup, elevations,
# Nearest to two: four, three, one, five, six, seven, zero, eight,
# Nearest to many: some, several, these, kitab, most, their, other, comoros,
# Nearest to first: last, jacquard, next, second, army, conceptual, same, vehicular,
# Nearest to that: which, this, what, however, but, assertions, daikaiju, knit,
# Nearest to for: after, of, laughed, atheroma, quarterly, national, through, last,
# Nearest to is: was, has, are, be, questioned, when, but, honorary,
# Nearest to these: some, many, all, their, other, such, both, they,
# Nearest to time: cafes, deceive, result, suspensions, nchen, professionally, norwood, buds,
# Nearest to over: fpga, gren, vangelis, discourage, deluge, wissenschaften, ctesiphon, sasquatch,
# Nearest to not: they, there, you, supercomputer, also, foresaw, hung, now,
# Average loss at step 32000: 3.501995
# Average loss at step 34000: 3.495089
# Average loss at step 36000: 3.456634
# Average loss at step 38000: 3.305962
# Average loss at step 40000: 3.428850
# Nearest to more: less, most, very, too, fairly, annuity, knitted, larger,
# Nearest to known: regarded, used, such, served, well, defined, considered, attenborough,
# Nearest to there: it, they, often, he, now, still, also, these,
# Nearest to d: b, UNK, rightmost, forall, varuna, ochre, peripheral, audacity,
# Nearest to states: nations, kingdom, univ, state, countries, katz, events, review,
# Nearest to b: d, r, conforms, solid, e, v, fortified, kate,
# Nearest to two: three, four, six, five, seven, one, eight, nine,
# Nearest to many: some, several, these, most, various, both, comoros, kitab,
# Nearest to first: second, last, next, jacquard, cliffs, falk, conceptual, carta,
# Nearest to that: which, what, this, however, also, because, lute, itself,
# Nearest to for: in, badge, atheroma, is, oregon, watercraft, fare, hellenized,
# Nearest to is: was, are, be, if, has, alibi, in, for,
# Nearest to these: many, some, all, both, those, several, their, such,
# Nearest to time: year, floss, norwood, grove, cafes, professionally, perennials, penance,
# Nearest to over: from, deluge, fpga, vangelis, sh, through, gren, unlike,
# Nearest to not: it, never, they, also, realistic, foresaw, here, now,
# Average loss at step 42000: 3.433494
# Average loss at step 44000: 3.456389
# Average loss at step 46000: 3.446270
# Average loss at step 48000: 3.355192
# Average loss at step 50000: 3.387009
# Nearest to more: less, most, very, knitted, fairly, hardwood, annuity, peppard,
# Nearest to known: regarded, used, served, such, well, defined, possible, considered,
# Nearest to there: they, it, he, often, now, she, still, we,
# Nearest to d: b, varuna, ward, dayton, forall, peripheral, kuwait, loomis,
# Nearest to states: kingdom, nations, univ, stabilization, review, ladders, fact, kriegsmarine,
# Nearest to b: d, r, v, solid, fortified, niles, w, frac,
# Nearest to two: one, three, four, five, six, eight, seven, zero,
# Nearest to many: some, several, these, various, both, most, certain, those,
# Nearest to first: last, second, next, final, jacquard, carta, third, same,
# Nearest to that: which, however, what, but, this, daikaiju, often, glacier,
# Nearest to for: professing, creates, including, after, christiaan, taps, diverting, from,
# Nearest to is: was, are, has, does, although, provides, platonist, became,
# Nearest to these: some, many, both, several, those, such, preponderance, all,
# Nearest to time: year, fungus, norwood, floss, goal, cafes, victory, penance,
# Nearest to over: fpga, gren, sh, off, vangelis, on, discourage, through,
# Nearest to not: now, realistic, never, they, who, liu, here, dedham,
# Average loss at step 52000: 3.437381
# Average loss at step 54000: 3.431075
# Average loss at step 56000: 3.435820
# Average loss at step 58000: 3.397058
# Average loss at step 60000: 3.392880
# Nearest to more: less, very, most, rather, too, larger, fairly, knitted,
# Nearest to known: regarded, used, served, such, well, defined, possible, considered,
# Nearest to there: they, it, now, still, he, we, this, often,
# Nearest to d: b, varuna, manuel, ward, lent, frac, forall, l,
# Nearest to states: kingdom, nations, countries, areas, state, fact, univ, ladders,
# Nearest to b: d, r, p, n, e, niles, fortified, nance,
# Nearest to two: three, four, five, six, one, eight, seven, zero,
# Nearest to many: some, several, these, various, certain, most, kitab, both,
# Nearest to first: second, last, final, jacquard, next, elite, falk, conceptual,
# Nearest to that: which, what, however, this, it, obtains, where, sole,
# Nearest to for: including, of, namely, atheroma, laughed, geographic, erratic, diverting,
# Nearest to is: was, are, has, although, be, remains, becomes, bidder,
# Nearest to these: many, those, some, several, both, which, such, all,
# Nearest to time: forgive, fungus, befall, victory, result, norwood, year, mission,
# Nearest to over: into, fpga, through, around, gren, deluge, restorative, multistage,
# Nearest to not: now, you, here, never, usually, they, readily, only,
# Average loss at step 62000: 3.242939
# Average loss at step 64000: 3.257378
# Average loss at step 66000: 3.403203
# Average loss at step 68000: 3.394292
# Average loss at step 70000: 3.362042
# Nearest to more: less, most, very, too, rather, knitted, larger, fairly,
# Nearest to known: regarded, used, served, such, defined, well, described, considered,
# Nearest to there: they, it, still, we, generally, now, often, he,
# Nearest to d: b, varuna, manuel, frac, lent, ward, l, caulfield,
# Nearest to states: kingdom, nations, countries, state, kneel, areas, univ, sawdust,
# Nearest to b: d, r, x, w, p, n, f, fortified,
# Nearest to two: three, four, six, one, five, seven, eight, zero,
# Nearest to many: some, several, various, most, these, all, certain, such,
# Nearest to first: second, last, next, same, original, final, jacquard, falk,
# Nearest to that: which, what, however, often, this, but, sedimentation, obtains,
# Nearest to for: in, atheroma, without, of, including, through, against, avalokitesvara,
# Nearest to is: was, has, be, are, indentured, became, although, becomes,
# Nearest to these: some, such, many, are, those, several, preponderance, their,
# Nearest to time: year, gruyter, fungus, reason, norwood, befall, forgive, place,
# Nearest to over: around, across, through, fpga, considerable, restorative, discourage, off,
# Nearest to not: now, usually, never, still, here, karin, numa, they,
# Average loss at step 72000: 3.372647
# Average loss at step 74000: 3.352258
# Average loss at step 76000: 3.318335
# Average loss at step 78000: 3.353768
# Average loss at step 80000: 3.377959
# Nearest to more: less, very, most, larger, rather, fairly, too, knitted,
# Nearest to known: regarded, used, served, defined, such, referred, described, considered,
# Nearest to there: they, it, he, still, she, we, now, often,
# Nearest to d: b, frac, lent, f, varuna, prerequisites, forall, talked,
# Nearest to states: kingdom, nations, state, countries, us, sawdust, manchester, nippur,
# Nearest to b: d, r, p, frac, fortified, w, f, x,
# Nearest to two: three, six, four, five, one, seven, eight, zero,
# Nearest to many: some, several, various, these, most, certain, both, few,
# Nearest to first: second, last, next, third, jacquard, final, same, prut,
# Nearest to that: which, however, what, where, furthermore, obtains, but, anime,
# Nearest to for: hellenized, mislead, recycle, atheroma, disturbance, in, briand, embracing,
# Nearest to is: was, has, are, be, became, although, were, refers,
# Nearest to these: several, many, those, some, such, various, are, both,
# Nearest to time: year, victory, swell, mission, norwood, intention, gruyter, befall,
# Nearest to over: around, across, through, fpga, off, multistage, into, place,
# Nearest to not: still, now, they, usually, never, readily, often, constantly,
# Average loss at step 82000: 3.408968
# Average loss at step 84000: 3.412476
# Average loss at step 86000: 3.393286
# Average loss at step 88000: 3.351553
# Average loss at step 90000: 3.361463
# Nearest to more: less, most, very, rather, larger, too, highly, knitted,
# Nearest to known: regarded, used, served, such, defined, possible, described, recognized,
# Nearest to there: they, it, he, still, we, she, now, generally,
# Nearest to d: b, f, prerequisites, varuna, lent, talked, utamaro, kuwait,
# Nearest to states: kingdom, nations, us, sawdust, countries, manchester, drove, state,
# Nearest to b: d, r, k, f, mannerisms, frac, y, p,
# Nearest to two: three, four, five, six, seven, one, eight, zero,
# Nearest to many: some, several, these, various, certain, most, all, those,
# Nearest to first: last, second, next, final, original, best, same, third,
# Nearest to that: which, however, what, furthermore, turgot, but, daikaiju, often,
# Nearest to for: of, including, after, qos, without, despite, diverting, during,
# Nearest to is: was, are, has, although, be, refers, does, were,
# Nearest to these: some, several, many, such, are, various, those, all,
# Nearest to time: mission, fungus, year, gruyter, manner, victory, befall, brief,
# Nearest to over: around, through, across, off, fpga, considerable, restorative, multistage,
# Nearest to not: still, now, karin, usually, they, never, actually, often,
# Average loss at step 92000: 3.400713
# Average loss at step 94000: 3.256865
# Average loss at step 96000: 3.355452
# Average loss at step 98000: 3.244988
# Average loss at step 100000: 3.360020
# Nearest to more: less, most, very, larger, highly, fairly, too, rather,
# Nearest to known: regarded, used, defined, such, served, possible, described, considered,
# Nearest to there: they, it, he, we, now, still, she, often,
# Nearest to d: b, w, barry, audacity, frac, k, f, loomis,
# Nearest to states: kingdom, nations, us, manchester, jurisdictions, countries, events, areas,
# Nearest to b: d, rightmost, ward, w, ltd, yassin, lookup, sized,
# Nearest to two: four, three, five, six, seven, one, eight, zero,
# Nearest to many: some, several, these, various, certain, all, such, those,
# Nearest to first: last, second, next, final, third, original, best, jacquard,
# Nearest to that: which, what, however, actually, but, this, lute, expects,
# Nearest to for: including, without, after, before, when, conifer, atheroma, erratic,
# Nearest to is: was, has, became, refers, provides, are, be, becomes,
# Nearest to these: several, many, some, various, those, were, such, certain,
# Nearest to time: year, mission, befall, reason, fungus, combinations, place, manner,
# Nearest to over: across, through, around, restorative, considerable, carbonyl, fpga, slammed,
# Nearest to not: still, never, you, now, they, readily, t, otherwise,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))    # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                                     ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0
#take original function and rewrite batch,label section
def generate_batch_cbow(batch_size, num_skips, skip_window):
    
    global data_index
    assert skip_window%2==1

    span = 2 * skip_window + 1 

    batch = np.ndarray(shape=(batch_size,span-1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    
    buffer = collections.deque(maxlen=span)

    #get words starting from index 0 to span
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    #2d batch form
    for i in range(batch_size):
        target = skip_window  # target label at the center of the buffer
        # add selected target to avoid_list for next time
        target_to_avoid = [ skip_window ] # we only need to know the words around a given word, not the word itself 
        col = 0
        for j in range(span):
            if j==span//2:
                continue
            
            batch[i,col] = buffer[j] # [skip_window] => middle element
            col += 1
        labels[i, 0] = buffer[target]

        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)

    assert batch.shape[0]==batch_size and batch.shape[1]== span-1
    return batch, labels

# %%
#take original block and rewrite embeddings to add averaging
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, 2*skip_window])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, embedding_size],
                                                 stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    #make cbow embeds and average and loss
    embeds = None
    for i in range(2*skip_window):
        embed_i = tf.nn.embedding_lookup(embeddings, train_dataset[:,i])
        print('embedding %d shape: %s'%(i,embed_i.get_shape().as_list()))
        embed_x,embed_y = embed_i.get_shape().as_list()
        if embeds is None:
            embeds = tf.reshape(embed_i,[embed_x,embed_y,1])
        else:
            embeds = tf.concat([embeds,tf.reshape(embed_i,[embed_x,embed_y,1])],2) #over z axis

    assert embeds.get_shape().as_list()[2]==2*skip_window
    print("Concat embedding size: %s"%embeds.get_shape().as_list())
    avg_embed =  tf.reduce_mean(embeds,2,keep_dims=False) #over z axis
    print("Avg embedding size: %s"%avg_embed.get_shape().as_list())
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=avg_embed,
                                                             labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
        normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# embedding 0 shape: [128, 128]
# embedding 1 shape: [128, 128]
# Concat embedding size: [128, 128, 2]
# Avg embedding size: [128, 128]

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.global_variables_initializer().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch_cbow(batch_size, num_skips, skip_window) #change the batch call only
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
                # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.381174
# Nearest to UNK: ararat, vigilantes, nel, amoxicillin, macmanus, hm, soldiery, mosaic,
# Nearest to would: aspartame, tyrosine, hypercard, spouse, bug, climbers, benevento, torrent,
# Nearest to people: malan, caller, mich, bamberger, azo, domitian, cataloguing, insensitivity,
# Nearest to had: duke, overthrew, coughing, homotopy, peano, twas, culminating, gustloff,
# Nearest to more: supervises, regard, homeomorphisms, ppc, ryaku, bagpuss, anomalous, edwards,
# Nearest to known: goats, spoof, erased, comstock, polonia, coffins, revisited, carbonic,
# Nearest to new: waterways, borel, goldsmiths, optimization, squarely, maury, specify, holiday,
# Nearest to they: geminate, albury, tunings, legislate, olives, torment, selangor, quarrel,
# Nearest to this: fulfil, chronica, assays, contain, desai, bouts, nepeta, litmus,
# Nearest to if: troopers, kinsmen, conceive, buccaneers, righteousness, brentwood, hainan, olga,
# Nearest to system: subsection, crawl, millie, convection, homogeneous, satirised, liars, heterosexism,
# Nearest to or: mediums, trilemma, survives, economical, authored, roofed, mechanization, ohlin,
# Nearest to in: puns, electron, ararat, stemming, pseudo, glorify, incur, performance,
# Nearest to some: translocation, jinnah, sink, emulate, jolson, masoretic, angelina, pauli,
# Nearest to into: regulate, irrealism, riddles, rambling, conciliatory, stanza, nativity, salutation,
# Nearest to an: ortelius, besieging, practitioners, gch, rub, gama, armed, aussie,
# Average loss at step 2000: 4.037508
# Average loss at step 4000: 3.510875
# Average loss at step 6000: 3.342373
# Average loss at step 8000: 3.193329
# Average loss at step 10000: 3.151480
# Nearest to UNK: beatification, receptors, demi, citizenry, akkadian, loudspeaker, maximally, remarking,
# Nearest to would: may, can, must, will, should, bug, afonso, do,
# Nearest to people: malan, household, strau, unnamed, cannon, lampoon, mich, chaucer,
# Nearest to had: has, was, have, were, cornish, supports, having, coughing,
# Nearest to more: gon, heightened, supervises, tropic, rather, decker, panentheistic, nouveaux,
# Nearest to known: goats, forum, revisited, well, sometimes, surmised, personal, guitars,
# Nearest to new: waterways, goldsmiths, stele, reenactment, specify, moivre, burke, district,
# Nearest to they: he, there, we, additive, heb, you, insects, auchinleck,
# Nearest to this: it, the, fulfil, mychal, their, geography, jarman, belli,
# Nearest to if: kinsmen, where, hainan, troopers, muslim, should, marie, before,
# Nearest to system: convection, missourians, government, homogeneous, bbl, careful, ciudad, mycological,
# Nearest to or: and, economical, bainbridge, roofed, faroes, rossini, mazes, disrupt,
# Nearest to in: during, at, on, between, among, puns, from, glorify,
# Nearest to some: any, many, most, other, allotrope, respondents, gods, angelina,
# Nearest to into: for, in, superstructure, by, christadelphians, within, conciliatory, among,
# Nearest to an: the, armed, specie, aussie, besieging, archaeopteryx, checkers, practitioners,
# Average loss at step 12000: 3.169071
# Average loss at step 14000: 3.123517
# Average loss at step 16000: 3.151576
# Average loss at step 18000: 3.102333
# Average loss at step 20000: 2.994216
# Nearest to UNK: de, beatification, tychonoff, walter, dora, jerzy, citizenry, earliest,
# Nearest to would: may, can, will, must, should, could, might, cannot,
# Nearest to people: malan, strau, timaeus, cannon, others, ranging, unnamed, anticipating,
# Nearest to had: has, have, was, having, cornish, were, married, supports,
# Nearest to more: less, most, rather, heightened, tropic, gon, supervises, very,
# Nearest to known: regarded, goats, well, revisited, defined, used, ibos, coffins,
# Nearest to new: goldsmiths, moivre, stele, polis, burke, ritter, waterways, reenactment,
# Nearest to they: we, he, there, you, heb, she, additive, pullback,
# Nearest to this: which, it, that, fulfil, mychal, the, belli, menstruation,
# Nearest to if: where, hainan, before, kinsmen, should, because, makes, nuncio,
# Nearest to system: millie, homogeneous, careful, bbl, convection, afb, shortcuts, missourians,
# Nearest to or: and, economical, than, uat, bainbridge, alternatives, roofed, perpendicular,
# Nearest to in: during, among, at, on, between, glorify, iho, towards,
# Nearest to some: many, any, these, most, angelina, allotrope, guru, all,
# Nearest to into: for, through, within, superstructure, rit, among, rambling, irrealism,
# Nearest to an: archaeopteryx, specie, aussie, incurable, fueled, elitism, armed, turpin,
# Average loss at step 22000: 3.050268
# Average loss at step 24000: 3.021957
# Average loss at step 26000: 2.989156
# Average loss at step 28000: 3.015211
# Average loss at step 30000: 2.989325
# Nearest to UNK: walter, hm, l, erotica, de, mesures, exhorts, w,
# Nearest to would: will, may, can, could, must, might, should, cannot,
# Nearest to people: malan, strau, others, timaeus, cannon, lampoon, works, unnamed,
# Nearest to had: has, have, was, having, were, saw, cornish, yet,
# Nearest to more: less, most, rather, very, heightened, tropic, smaller, extremely,
# Nearest to known: regarded, defined, goats, possible, used, well, described, rightly,
# Nearest to new: goldsmiths, moivre, stele, sociobiology, polis, protege, deny, ritter,
# Nearest to they: we, he, there, you, she, it, heb, pullback,
# Nearest to this: which, it, shaikh, that, fulfil, the, heterozygote, anglian,
# Nearest to if: where, when, before, because, hainan, though, should, nuncio,
# Nearest to system: millie, banjos, careful, circus, shortcuts, homogeneous, bbl, davison,
# Nearest to or: and, than, bainbridge, economical, alternatives, centralisation, uat, foreskin,
# Nearest to in: during, among, within, throughout, at, under, from, on,
# Nearest to some: many, any, several, these, most, angelina, certain, various,
# Nearest to into: through, rit, superstructure, within, from, irrealism, fireman, psychologists,
# Nearest to an: archaeopteryx, aussie, specie, fueled, besieging, incurable, armed, elitism,
# Average loss at step 32000: 2.843937
# Average loss at step 34000: 2.940957
# Average loss at step 36000: 2.939742
# Average loss at step 38000: 2.934008
# Average loss at step 40000: 2.922318
# Nearest to UNK: jerzy, o, columbanus, l, lem, reviled, petitcodiac, restated,
# Nearest to would: will, can, may, could, might, must, should, cannot,
# Nearest to people: strau, malan, lampoon, others, timaeus, cultures, cannon, works,
# Nearest to had: has, have, was, were, saw, having, londoners, already,
# Nearest to more: less, most, very, rather, tropic, heightened, smaller, simultaneously,
# Nearest to known: regarded, defined, used, possible, described, goats, integrase, expressed,
# Nearest to new: goldsmiths, moivre, sociobiology, protege, ritter, stele, burke, ponty,
# Nearest to they: we, he, there, you, she, it, pullback, who,
# Nearest to this: which, it, shaikh, what, heterozygote, your, fulfil, that,
# Nearest to if: when, where, before, because, though, hainan, precautionary, should,
# Nearest to system: banjos, millie, systems, circus, silt, careful, davison, shortcuts,
# Nearest to or: and, alternatives, than, roofed, bainbridge, narcotic, uat, though,
# Nearest to in: during, among, throughout, within, at, glorify, tragedians, sei,
# Nearest to some: many, several, any, most, these, various, certain, all,
# Nearest to into: through, across, from, within, fireman, rit, kali, trafficking,
# Nearest to an: elitism, archaeopteryx, aussie, prevail, muon, fueled, incurable, specie,
# Average loss at step 42000: 2.939470
# Average loss at step 44000: 2.944413
# Average loss at step 46000: 2.898410
# Average loss at step 48000: 2.870482
# Average loss at step 50000: 2.841916
# Nearest to UNK: von, warn, scott, loudspeaker, el, et, hm, missourians,
# Nearest to would: will, may, could, can, might, should, must, cannot,
# Nearest to people: malan, timaeus, strau, lampoon, cultures, others, mutilated, women,
# Nearest to had: has, have, was, were, saw, having, already, spend,
# Nearest to more: less, most, very, rather, better, nouveaux, highly, tropic,
# Nearest to known: regarded, defined, used, possible, described, goats, such, expressed,
# Nearest to new: goldsmiths, sociobiology, specific, ponty, moivre, cathy, lomond, stele,
# Nearest to they: we, there, he, you, she, it, pullback, these,
# Nearest to this: it, which, shaikh, the, some, what, heterozygote, another,
# Nearest to if: when, where, because, though, before, since, should, so,
# Nearest to system: systems, banjos, millie, circus, improvisational, silt, shortcuts, undermines,
# Nearest to or: and, alternatives, than, bainbridge, while, economical, grrm, atmospheric,
# Nearest to in: during, within, at, on, throughout, among, glorify, iho,
# Nearest to some: many, several, any, these, certain, most, various, multiple,
# Nearest to into: through, across, within, from, kali, fireman, trafficking, rit,
# Nearest to an: archaeopteryx, operas, elitism, muon, aussie, fueled, besieging, prevail,
# Average loss at step 52000: 2.885546
# Average loss at step 54000: 2.860036
# Average loss at step 56000: 2.857895
# Average loss at step 58000: 2.759494
# Average loss at step 60000: 2.824819
# Nearest to UNK: von, l, crashes, hm, der, recoup, et, portillo,
# Nearest to would: will, could, may, can, might, must, should, cannot,
# Nearest to people: malan, timaeus, strau, children, lampoon, women, cultures, others,
# Nearest to had: has, have, was, were, having, saw, suffered, londoners,
# Nearest to more: less, most, very, rather, nouveaux, highly, better, tropic,
# Nearest to known: regarded, defined, possible, used, such, described, expressed, goats,
# Nearest to new: goldsmiths, specific, moivre, ponty, sociobiology, lomond, humboldt, indulged,
# Nearest to they: we, he, there, you, she, it, heb, these,
# Nearest to this: which, it, some, the, shaikh, what, another, gholas,
# Nearest to if: when, where, because, though, before, empties, after, should,
# Nearest to system: systems, banjos, millie, silt, improvisational, circus, process, undermines,
# Nearest to or: and, than, alternatives, dumping, though, economical, atmospheric, narcotic,
# Nearest to in: during, within, at, throughout, among, iho, near, on,
# Nearest to some: many, several, any, most, these, certain, guru, this,
# Nearest to into: through, within, across, from, kali, trafficking, irrealism, fireman,
# Nearest to an: coronary, archaeopteryx, operas, muon, specie, prevail, aussie, recursion,
# Average loss at step 62000: 2.833549
# Average loss at step 64000: 2.774925
# Average loss at step 66000: 2.765083
# Average loss at step 68000: 2.718546
# Average loss at step 70000: 2.770788
# Nearest to UNK: der, careless, genuinely, playwright, codomain, greenspan, transplant, panini,
# Nearest to would: will, could, might, may, can, must, should, cannot,
# Nearest to people: women, children, malan, strau, timaeus, lampoon, cultures, jews,
# Nearest to had: has, have, was, having, were, saw, londoners, suffered,
# Nearest to more: less, most, very, better, nouveaux, highly, rather, tropic,
# Nearest to known: regarded, defined, possible, described, such, used, expressed, goats,
# Nearest to new: specific, sociobiology, moivre, great, goldsmiths, humboldt, schuler, patriotic,
# Nearest to they: we, he, there, you, she, it, these, heb,
# Nearest to this: which, it, shaikh, each, what, some, anglian, the,
# Nearest to if: when, where, because, though, before, since, follows, after,
# Nearest to system: systems, banjos, millie, device, process, silt, improvisational, clutter,
# Nearest to or: and, than, alternatives, lone, though, bainbridge, marcus, economical,
# Nearest to in: within, during, at, throughout, on, under, iho, of,
# Nearest to some: many, several, any, these, most, certain, various, guru,
# Nearest to into: through, within, across, from, trafficking, kali, singles, uplands,
# Nearest to an: aussie, elitism, operas, muon, archaeopteryx, coronary, besieging, fitted,
# Average loss at step 72000: 2.803592
# Average loss at step 74000: 2.653791
# Average loss at step 76000: 2.802566
# Average loss at step 78000: 2.823917
# Average loss at step 80000: 2.785113
# Nearest to UNK: baptiste, der, hm, du, el, coven, fein, dora,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to people: children, women, jews, timaeus, things, months, malan, others,
# Nearest to had: has, have, having, were, was, saw, suffered, londoners,
# Nearest to more: less, most, very, highly, nouveaux, better, rather, extremely,
# Nearest to known: regarded, defined, possible, used, described, such, expressed, abbreviated,
# Nearest to new: specific, moivre, goldsmiths, sociobiology, slipknot, humboldt, samir, lomond,
# Nearest to they: we, he, you, there, she, it, i, these,
# Nearest to this: which, it, shaikh, that, another, some, what, each,
# Nearest to if: when, where, before, though, since, because, follows, so,
# Nearest to system: systems, banjos, millie, device, silt, process, improvisational, dislocations,
# Nearest to or: and, than, alternatives, though, lone, marsalis, bainbridge, economical,
# Nearest to in: during, within, at, on, throughout, near, under, iho,
# Nearest to some: many, several, certain, any, most, these, various, both,
# Nearest to into: through, within, across, from, trafficking, kali, uplands, singles,
# Nearest to an: archaeopteryx, elitism, operas, aussie, muon, bangla, incurable, besieging,
# Average loss at step 82000: 2.674991
# Average loss at step 84000: 2.779050
# Average loss at step 86000: 2.744278
# Average loss at step 88000: 2.758263
# Average loss at step 90000: 2.743983
# Nearest to UNK: hm, et, dora, baptiste, liqueurs, scott, tychonoff, angel,
# Nearest to would: will, could, might, may, can, should, must, cannot,
# Nearest to people: women, children, jews, strau, men, cultures, things, players,
# Nearest to had: has, have, was, were, having, saw, suffered, wanted,
# Nearest to more: less, most, very, highly, better, nouveaux, rather, extremely,
# Nearest to known: regarded, defined, possible, used, described, expressed, intended, abbreviated,
# Nearest to new: specific, moivre, sociobiology, radical, patriotic, sio, liberal, slipknot,
# Nearest to they: we, he, there, you, she, it, i, these,
# Nearest to this: which, it, shaikh, what, another, the, each, that,
# Nearest to if: when, though, before, where, since, follows, because, so,
# Nearest to system: systems, banjos, device, millie, improvisational, process, favours, clutter,
# Nearest to or: and, though, than, lone, alternatives, bainbridge, while, fayyum,
# Nearest to in: within, during, throughout, on, near, at, among, airman,
# Nearest to some: many, several, certain, most, any, various, these, multiple,
# Nearest to into: through, within, from, across, onto, trafficking, kali, uplands,
# Nearest to an: archaeopteryx, operas, bangla, aussie, coronary, elitism, ksc, muon,
# Average loss at step 92000: 2.686241
# Average loss at step 94000: 2.725010
# Average loss at step 96000: 2.709973
# Average loss at step 98000: 2.385332
# Average loss at step 100000: 2.423620
# Nearest to UNK: von, hm, tychonoff, dora, alighieri, exhorts, du, der,
# Nearest to would: will, could, might, can, should, may, must, cannot,
# Nearest to people: children, jews, women, men, strau, timaeus, things, speakers,
# Nearest to had: has, have, was, saw, having, were, wanted, suffered,
# Nearest to more: less, most, very, better, highly, rather, nouveaux, enough,
# Nearest to known: regarded, defined, used, possible, described, expressed, opposed, abbreviated,
# Nearest to new: moivre, specific, lombardo, sio, samir, sociobiology, goldsmiths, next,
# Nearest to they: we, he, there, you, she, it, i, never,
# Nearest to this: which, it, shaikh, another, some, what, each, tombaugh,
# Nearest to if: when, though, before, where, follows, since, after, so,
# Nearest to system: systems, device, banjos, process, favours, improvisational, millie, situation,
# Nearest to or: and, than, lone, alternatives, though, bainbridge, dowling, ec,
# Nearest to in: during, within, at, near, throughout, activate, on, ris,
# Nearest to some: many, several, certain, any, most, various, multiple, both,
# Nearest to into: through, within, across, from, fireman, kali, onto, uplands,
# Nearest to an: operas, aussie, archaeopteryx, ksc, coronary, fueled, elitism, muon,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))    # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                                     ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
